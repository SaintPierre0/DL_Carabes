# %%
# import PyTorch and its related packages
import torch as T
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import torch

import torchvision
import torchvision.transforms as transforms

from torchvision import transforms
from torchvision.datasets import ImageFolder

from tqdm.notebook import tqdm

from sklearn.metrics import confusion_matrix


# set default device based on CUDA's availability
device = 'cuda' if T.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
transform = transforms.Compose(
    [transforms.Resize((512,512)),
     transforms.ToTensor(),
     transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))])

batch_size = 64
#image_size = (224, 224, 3)

train_set = ImageFolder('C:/Users/heuma/Desktop/Master/S10/Aurea/Dataset_pretrained_model/modified/TRAIN/', transform=transform)
test_set = ImageFolder('C:/Users/heuma/Desktop/Master/S10/Aurea/Dataset_pretrained_model/modified/TEST/', transform=transform)

#train_set = train_ds
train_loader = T.utils.data.DataLoader(train_set, batch_size=batch_size,shuffle=True, num_workers=4)

#test_set = test_ds
test_loader = T.utils.data.DataLoader(test_set, batch_size=batch_size,shuffle=False, num_workers=4)

# %%
class NewNetwork(nn.Module):
    def __init__(self, num_classes=16):
        super(NewNetwork, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, out_channels = 32, kernel_size=3, stride=2, padding=1), #224
            nn.PReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.1),
            nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1),
            nn.PReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.2),
            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),#112
            nn.Conv2d(128, 128, kernel_size=3, stride=2, padding=1),
            nn.PReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.3),
            nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1),#56
            nn.PReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.4)
            #nn.Conv2d(256, 512, kernel_size=5, stride=2, padding=1), #28
            #nn.ReLU(inplace=True),
            #nn.MaxPool2d(kernel_size=2, stride=2),
            #nn.Dropout(p=0.5)
            
           
        )
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(4 * 8 * 8, 1000), #mettre 128 quand il y a 5 couches
            nn.PReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(1000, 1000),
            nn.PReLU(),
            nn.Linear(1000, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.shape[0], -1)
        x = self.classifier(x)
        return x

# %%
net = NewNetwork()
net.to(device)
# Out:
# NewNetwork(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): PReLU(num_parameters=1)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): PReLU(num_parameters=1)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (9): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (10): PReLU(num_parameters=1)
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Dropout(p=0.3, inplace=False)
#     (13): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (14): PReLU(num_parameters=1)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (16): Dropout(p=0.4, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=256, out_features=1000, bias=True)
#     (2): PReLU(num_parameters=1)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=1000, out_features=1000, bias=True)
#     (5): PReLU(num_parameters=1)
#     (6): Linear(in_features=1000, out_features=16, bias=True)
#   )
# )

# %%
criterion = nn.CrossEntropyLoss()

# also the optimizer
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

#dynamic learning rate
#scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)

# %%
train_loss = []
test_loss = []
train_acc = []
test_acc = []

lrs = []
steps = []

# Initialize the prediction and label lists(tensors)
predlist=torch.zeros(0,dtype=torch.long, device='cpu')
lbllist=torch.zeros(0,dtype=torch.long, device='cpu')

for epoch in tqdm(range(0, 300)):  # loop over the dataset multiple times
    
    running_loss = .0
    correct = 0
    total = 0
    for i, data in enumerate(train_loader):
        # get the inputs
        inputs, labels = data
        if device == 'cuda':
            inputs, labels = inputs.to(device), labels.to(device)

        # reset the parameter gradients
        optimizer.zero_grad()

        # forward
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        # backward
        loss.backward()
        # optimize
        optimizer.step()
        
        running_loss += loss.item()
        _, predicted = T.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        
    running_loss /= len(train_loader)
    train_loss.append(running_loss)
    running_acc = correct / total
    train_acc.append(running_acc)
    
    #zone pour mettre le learning rate dynamique
    """
    steps.append(epoch)
    lrs.append(scheduler.get_last_lr()[0])
    scheduler.step()
    """
    
    if epoch % 10 == 0:
        print('\nEpoch: {}'.format(epoch))
        print('Train Acc. => {:.3f}%'.format(100 * running_acc), end=' | ')
        print('Train Loss => {:.5f}'.format(running_loss))
    
    # evaluate on the test set
    # note this is usually performed on the validation set
    # for simplicity we just evaluate it on the test set
    with T.no_grad():
        correct = 0
        total = 0
        test_running_loss = .0
        for data in test_loader:
            inputs, labels = data
            if device == 'cuda':
                inputs, labels = inputs.to(device), labels.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            test_running_loss += loss.item()
            _, predicted = T.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            
            # Append batch prediction results
            predlist=torch.cat([predlist,predicted.view(-1).cpu()])
            lbllist=torch.cat([lbllist,labels.view(-1).cpu()])

        test_running_loss /= len(test_loader)
        test_loss.append(test_running_loss)
        test_running_acc = correct / total
        test_acc.append(test_running_acc)
        
        if epoch % 10 == 0:
            print('Test Acc.  => {:.3f}%'.format(100 * test_running_acc), end=' | ')
            print('Test Loss  => {:.5f}'.format(test_running_loss))

print('Finished Training')
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# Epoch: 0
# Train Acc. => 12.711% | Train Loss => 2.76126
# Test Acc.  => 16.163% | Test Loss  => 2.74806
#
# Epoch: 10
# Train Acc. => 15.692% | Train Loss => 2.53011
# Test Acc.  => 16.519% | Test Loss  => 2.52481
#
# Epoch: 20
# Train Acc. => 21.871% | Train Loss => 2.21484
# Test Acc.  => 27.176% | Test Loss  => 2.08691
#
# Epoch: 30
# Train Acc. => 42.350% | Train Loss => 1.62005
# Test Acc.  => 42.984% | Test Loss  => 1.53441
#
# Epoch: 40
# Train Acc. => 53.335% | Train Loss => 1.28461
# Test Acc.  => 56.483% | Test Loss  => 1.26995
#
# Epoch: 50
# Train Acc. => 61.965% | Train Loss => 1.05553
# Test Acc.  => 60.036% | Test Loss  => 1.08243
#
# Epoch: 60
# Train Acc. => 68.713% | Train Loss => 0.85882
# Test Acc.  => 65.009% | Test Loss  => 0.95460
#
# Epoch: 70
# Train Acc. => 74.539% | Train Loss => 0.71200
# Test Acc.  => 68.028% | Test Loss  => 0.92566
#
# Epoch: 80
# Train Acc. => 77.246% | Train Loss => 0.61691
# Test Acc.  => 69.272% | Test Loss  => 0.78939
#
# Epoch: 90
# Train Acc. => 81.385% | Train Loss => 0.50431
# Test Acc.  => 74.423% | Test Loss  => 0.74823
#
# Epoch: 100
# Train Acc. => 84.719% | Train Loss => 0.42139
# Test Acc.  => 76.199% | Test Loss  => 0.65166
#
# Epoch: 110
# Train Acc. => 87.015% | Train Loss => 0.35898
# Test Acc.  => 75.844% | Test Loss  => 0.65224
#
# Epoch: 120
# Train Acc. => 88.074% | Train Loss => 0.31353
# Test Acc.  => 78.330% | Test Loss  => 0.65141
#
# Epoch: 130
# Train Acc. => 90.330% | Train Loss => 0.26896
# Test Acc.  => 80.107% | Test Loss  => 0.55192
#
# Epoch: 140
# Train Acc. => 91.585% | Train Loss => 0.22009
# Test Acc.  => 77.265% | Test Loss  => 0.70399
#
# Epoch: 150
# Train Acc. => 92.507% | Train Loss => 0.20748
# Test Acc.  => 76.377% | Test Loss  => 0.69298
#
# Epoch: 160
# Train Acc. => 92.605% | Train Loss => 0.19444
# Test Acc.  => 74.956% | Test Loss  => 0.76789
#
# Epoch: 170
# Train Acc. => 93.625% | Train Loss => 0.17209
# Test Acc.  => 79.751% | Test Loss  => 0.64055
#
# Epoch: 180
# Train Acc. => 94.449% | Train Loss => 0.15217
# Test Acc.  => 77.620% | Test Loss  => 0.76810
#
# Epoch: 190
# Train Acc. => 94.998% | Train Loss => 0.13473
# Test Acc.  => 79.929% | Test Loss  => 0.76601
#
# Epoch: 200
# Train Acc. => 95.508% | Train Loss => 0.11874
# Test Acc.  => 79.929% | Test Loss  => 0.83531
#
# Epoch: 210
# Train Acc. => 96.371% | Train Loss => 0.10310
# Test Acc.  => 79.218% | Test Loss  => 0.79320
#
# Epoch: 220
# Train Acc. => 96.587% | Train Loss => 0.09678
# Test Acc.  => 81.883% | Test Loss  => 0.72665
#
# Epoch: 230
# Train Acc. => 96.371% | Train Loss => 0.10031
# Test Acc.  => 77.975% | Test Loss  => 0.84778
#
# Epoch: 240
# Train Acc. => 96.960% | Train Loss => 0.09128
# Test Acc.  => 78.686% | Test Loss  => 0.86090
#
# Epoch: 250
# Train Acc. => 97.940% | Train Loss => 0.06212
# Test Acc.  => 79.041% | Test Loss  => 1.02573
#
# Epoch: 260
# Train Acc. => 97.568% | Train Loss => 0.06711
# Test Acc.  => 82.771% | Test Loss  => 0.79882
#
# Epoch: 270
# Train Acc. => 97.548% | Train Loss => 0.06977
# Test Acc.  => 78.863% | Test Loss  => 0.96982
#
# Epoch: 280
# Train Acc. => 97.921% | Train Loss => 0.05703
# Test Acc.  => 81.172% | Test Loss  => 0.89699
#
# Epoch: 290
# Train Acc. => 98.097% | Train Loss => 0.05410
# Test Acc.  => 79.751% | Test Loss  => 0.93315
# Finished Training

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Confusion matrix
conf_mat=confusion_matrix(lbllist.numpy(), predlist.numpy())
print(conf_mat)
# Out:
# [[24359   245   259    16     5   444    71   334    23   176     8   281
#     745   188   145     1]
#  [ 1405  8814   111  1894     5   792     4   383   116    77     0   493
#       3     0     3     0]
#  [ 1531   113  9138   173   328   173  1230     7   774     0   615    10
#       0     0     8     0]
#  [  671  3755    43   960     1   242     3    66    40    63     0   155
#       1     0     0     0]
#  [  728    11   233     0  9481     8   278     0   292     0     5     0
#       0     0    64     0]
#  [ 2581   542   498   167    15  8226   425   233   479     6    21     3
#       1     0     3     0]
#  [  725    17  1154     5  1290    30  4467     0   358     0   304     1
#       0     0    47     2]
#  [ 1129   488    39    24     0   554     0  7047    57    42     0   220
#       0     0     0     0]
#  [ 1091    59   413     1   446   133    58     3 13384     0     1     5
#       0     0     6     0]
#  [  606   109     0    14     0     3     0   217     0  5098     0   474
#     356    22     1     0]
#  [  140     4   241     2   270     7   863     0   126     0   425     0
#       0     0    22     0]
#  [  815   824    42    37     0    43     0   511    25   316     0  6683
#       3     0     1     0]
#  [ 1001     5     0     3     0     0     0     2     0   125     0     3
#    8980   679     2     0]
#  [  637     5     1     0     0     0     0     0     0    74     0    13
#    2451  2812     7     0]
#  [  580     1     0     0    20     0     0     0     1     0     0     3
#       0     0  7248  3547]
#  [  154     1     0     0     6     0     0     0     2     1     0     3
#       0     0  1596  1237]]

# %%
fig, ax = plt.subplots(figsize=(13,10))
sns.heatmap(conf_mat, annot=True, ax=ax)
# Out:
# <AxesSubplot:>

# %%
# Per-class accuracy
class_accuracy=100*conf_mat.diagonal()/conf_mat.sum(1)
print(class_accuracy)
# Out:
# [89.22710623 62.5106383  64.80851064 16.         85.41441441 62.31818182
#  53.17857143 73.40625    85.79487179 73.88405797 20.23809524 71.86021505
#  83.14814815 46.86666667 63.57894737 41.23333333]

# %%
"""
plt.plot(steps, lrs)
plt.xlabel("epoch")
plt.ylabel("learning rate values")
plt.title("learning rate's curve")
plt.show()
"""
# Out:
# '\nplt.plot(steps, lrs)\nplt.xlabel("epoch")\nplt.ylabel("learning rate values")\nplt.title("learning rate\'s curve")\nplt.show()\n'

# %%
plt.plot(train_loss, label='train')
plt.plot(test_loss, label='test')
plt.xlabel("epoch")
plt.ylabel("loss values")
plt.title("loss rate's curve")
plt.legend()
plt.show()

# %%
plt.plot(train_acc, label='train')
plt.plot(test_acc, label='test')
plt.xlabel("epoch")
plt.ylabel("accuracy values")
plt.title("accuracy rate's curve")
plt.legend()
plt.show()

# %%
torch.save(net.state_dict(), "C:/Users/heuma/Desktop/Master/S10/Aurea/Saved_Network/dict_Linh_network_4th_try_16species")

# %%
torch.save(net, "C:/Users/heuma/Desktop/Master/S10/Aurea/Saved_Network/Linh_network_entire_model_4th_try_16species")

# %%
"""
from torch.utils.data.dataloader import DataLoader


train_dl = DataLoader(train_set, batch_size, shuffle = True, num_workers = 4, pin_memory = True)

from torchvision.utils import make_grid

def show_batch(dl):
    #Plot images grid of single batch
    for images, labels in dl:
        fig,ax = plt.subplots(figsize = (16,12))
        ax.set_xticks([])
        ax.set_yticks([])
        ax.imshow(make_grid(images,nrow=16).permute(1,2,0))
        break
        
show_batch(train_dl)

"""
# Out:
# '\nfrom torch.utils.data.dataloader import DataLoader\n\n\ntrain_dl = DataLoader(train_set, batch_size, shuffle = True, num_workers = 4, pin_memory = True)\n\nfrom torchvision.utils import make_grid\n\ndef show_batch(dl):\n    #Plot images grid of single batch\n    for images, labels in dl:\n        fig,ax = plt.subplots(figsize = (16,12))\n        ax.set_xticks([])\n        ax.set_yticks([])\n        ax.imshow(make_grid(images,nrow=16).permute(1,2,0))\n        break\n        \nshow_batch(train_dl)\n\n'

# %%
"""
transform2 = transforms.Compose(
    [transforms.Resize((224, 224)),
     transforms.ToTensor()])

train_set2 = ImageFolder('C:/Users/heuma/Desktop/Master/S10/Aurea/Dataset_Kaggle_Test_Train_20-80/TRAIN/', transform=transform2)

train_dl2 = DataLoader(train_set2, batch_size, shuffle = True, num_workers = 4, pin_memory = True)

        
show_batch(train_dl2)
"""
# Out:
# "\ntransform2 = transforms.Compose(\n    [transforms.Resize((224, 224)),\n     transforms.ToTensor()])\n\ntrain_set2 = ImageFolder('C:/Users/heuma/Desktop/Master/S10/Aurea/Dataset_Kaggle_Test_Train_20-80/TRAIN/', transform=transform2)\n\ntrain_dl2 = DataLoader(train_set2, batch_size, shuffle = True, num_workers = 4, pin_memory = True)\n\n        \nshow_batch(train_dl2)\n"

# %% [markdown]
# ## Load Model

# %%
net = NewNetwork()
net.load_state_dict(torch.load('C:/Users/heuma/Desktop/Master/S10/Aurea/Saved_Network/dict_Linh_network_4th_try_16species'))
# Out:
# <All keys matched successfully>

# %%
net.to(device)
# Out:
# NewNetwork(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): PReLU(num_parameters=1)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): PReLU(num_parameters=1)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (9): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (10): PReLU(num_parameters=1)
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Dropout(p=0.3, inplace=False)
#     (13): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (14): PReLU(num_parameters=1)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (16): Dropout(p=0.4, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=256, out_features=1000, bias=True)
#     (2): PReLU(num_parameters=1)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=1000, out_features=1000, bias=True)
#     (5): PReLU(num_parameters=1)
#     (6): Linear(in_features=1000, out_features=16, bias=True)
#   )
# )

# %%
transform = transforms.Compose(
    [transforms.Resize((512,512)),
     transforms.ToTensor(),
     transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))])

batch_size = 64
#image_size = (224, 224, 3)

train_set = ImageFolder('C:/Users/heuma/Desktop/Master/S10/Aurea/Dataset_Kaggle_Test_Train_20-80/TRAIN/', transform=transform)
test_set = ImageFolder('C:/Users/heuma/Desktop/Master/S10/Aurea/Dataset_Kaggle_Test_Train_20-80/TEST/', transform=transform)

#train_set = train_ds
train_loader = T.utils.data.DataLoader(train_set, batch_size=batch_size,shuffle=True, num_workers=4)

#test_set = test_ds
test_loader = T.utils.data.DataLoader(test_set, batch_size=batch_size,shuffle=False, num_workers=4)
